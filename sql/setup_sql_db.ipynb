# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sqlalchemy.exc import ProgrammingError

# %%
load_dotenv()
# Out:
# True

# %%
USER = os.getenv("DB_USER")
PASSWORD = os.getenv("DB_PASSWORD")
HOST = os.getenv("DB_HOST")
PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

# %%
print(f"USER: {USER}")
print(f"PASSWORD: {PASSWORD[:1]}...{PASSWORD[-1:]}")
print(f"HOST: {HOST}")
print(f"PORT: {PORT}")
print(f"DB_NAME: {DB_NAME}")
# Out:
# USER: postgres
# PASSWORD: C...9
# HOST: localhost
# PORT: 5432
# DB_NAME: financial_db

# %%
ADMIN_URL = f"postgresql+psycopg://{USER}:{PASSWORD}@{HOST}:{PORT}/postgres"
admin_engine = create_engine(ADMIN_URL, isolation_level="AUTOCOMMIT")

# %%
print(f"Checking if database '{DB_NAME}' exists...")
with admin_engine.connect() as connection:
    try:
        connection.execute(text(f"CREATE DATABASE {DB_NAME};"))
        print(f"Database '{DB_NAME}' created successfully.")
    except ProgrammingError:
        # Catch exception if the database already exists
        print(f"Database '{DB_NAME}' already exists. Skipping initialization.")
# Out:
# Checking if database 'financial_db' exists...
# Database 'financial_db' already exists. Skipping initialization.

# %%
APP_DB_URL = f"postgresql+psycopg://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}"
app_engine = create_engine(APP_DB_URL)

# %%
print("Initializing database tables...")
with app_engine.connect() as connection:
    connection.execute(text("""
        CREATE TABLE IF NOT EXISTS projects (
            id SERIAL PRIMARY KEY,
            title VARCHAR(100) NOT NULL,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
    """))
    connection.commit()

print("Database initialization complete!")
# Out:
# Initializing database tables...
# Database initialization complete!
